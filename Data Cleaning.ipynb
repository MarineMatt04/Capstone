# %%
import pandas as pd
import numpy as np
import matplotlib as plot
import csv
import openpyxl
from datetime import datetime

# %%
weekend_movie_gross_excel = pd.read_excel(r"C:\Users\mattl\code\SavvyCoders\Capstone\Data Sets\Opening Weekend Gross.xlsx")

# %%
weekend_movie_gross_excel
# Out:
#                                                Release      Opening  \
# 0                                    Avengers: Endgame  357115007.0
# 1                              Spider-Man: No Way Home  260138569.0
# 2                               Avengers: Infinity War  257698183.0
# 3           Star Wars: Episode VII - The Force Awakens  247966675.0
# 4              Star Wars: Episode VIII - The Last Jedi  220009584.0
# ..                                                 ...          ...
# 995  Demon Slayer: Kimetsu no Yaiba - The Movie: Mu...   21234994.0
# 996                           Boo 2! A Madea Halloween   21226953.0
# 997                                            Payback   21221526.0
# 998                                      Four Brothers   21176925.0
# 999                                         Waterworld   21171780.0
#
#      Total Gross  % of Total  Theaters  Average       Date  \
# 0    858373000.0       0.416    4662.0  76601.0 2019-04-26
# 1    804793477.0       0.323    4336.0  59995.0 2021-12-17
# 2    678815482.0       0.380    4474.0  57599.0 2018-04-27
# 3    936662225.0       0.265    4134.0  59982.0 2015-12-18
# 4    620181382.0       0.355    4232.0  51987.0 2017-12-15
# ..           ...         ...       ...      ...        ...
# 995   49505008.0       0.429    1614.0  13156.0 2021-04-23
# 996   47319572.0       0.449    2388.0   8889.0 2017-10-20
# 997   81526121.0       0.260    2729.0   7776.0 1999-02-05
# 998   74494381.0       0.284    2533.0   8360.0 2005-08-12
# 999   88246220.0       0.240    2268.0   9335.0 1995-07-28
#
#                              Distributor
# 0    Walt Disney Studios Motion Pictures
# 1      Sony Pictures Entertainment (SPE)
# 2    Walt Disney Studios Motion Pictures
# 3    Walt Disney Studios Motion Pictures
# 4    Walt Disney Studios Motion Pictures
# ..                                   ...
# 995             FUNimation Entertainment
# 996                     Lions Gate Films
# 997                   Paramount Pictures
# 998                   Paramount Pictures
# 999                   Universal Pictures
#
# [1000 rows x 8 columns]

# %%
weekend_movie_gross_excel ['Date'].value_counts()
# Out:
# Date
# 2012-02-10    4
# 2017-02-10    3
# 2004-06-11    3
# 2016-07-22    3
# 2016-06-10    3
#              ..
# 1992-06-19    1
# 1996-05-22    1
# 2018-08-10    1
# 2001-08-10    1
# 1995-07-28    1
# Name: count, Length: 859, dtype: int64

# %%
weekend_movie_gross_excel.drop(['% of Total', 'Theaters', 'Average'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\mattl\code\SavvyCoders\Capstone\Data Cleaning.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mattl/code/SavvyCoders/Capstone/Data%20Cleaning.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> weekend_movie_gross_excel.drop(['% of Total', 'Theaters', 'Average'], axis=1, inplace=True)
#
# File c:\Users\mattl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File c:\Users\mattl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\mattl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Users\mattl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['% of Total', 'Theaters', 'Average'] not found in axis"

# %%
weekend_movie_gross_excel
# Out:
#                                                Release      Opening  \
# 0                                    Avengers: Endgame  357115007.0
# 1                              Spider-Man: No Way Home  260138569.0
# 2                               Avengers: Infinity War  257698183.0
# 3           Star Wars: Episode VII - The Force Awakens  247966675.0
# 4              Star Wars: Episode VIII - The Last Jedi  220009584.0
# ..                                                 ...          ...
# 995  Demon Slayer: Kimetsu no Yaiba - The Movie: Mu...   21234994.0
# 996                           Boo 2! A Madea Halloween   21226953.0
# 997                                            Payback   21221526.0
# 998                                      Four Brothers   21176925.0
# 999                                         Waterworld   21171780.0
#
#      Total Gross       Date                          Distributor
# 0    858373000.0 2019-04-26  Walt Disney Studios Motion Pictures
# 1    804793477.0 2021-12-17    Sony Pictures Entertainment (SPE)
# 2    678815482.0 2018-04-27  Walt Disney Studios Motion Pictures
# 3    936662225.0 2015-12-18  Walt Disney Studios Motion Pictures
# 4    620181382.0 2017-12-15  Walt Disney Studios Motion Pictures
# ..           ...        ...                                  ...
# 995   49505008.0 2021-04-23             FUNimation Entertainment
# 996   47319572.0 2017-10-20                     Lions Gate Films
# 997   81526121.0 1999-02-05                   Paramount Pictures
# 998   74494381.0 2005-08-12                   Paramount Pictures
# 999   88246220.0 1995-07-28                   Universal Pictures
#
# [1000 rows x 5 columns]

# %%
weekend_movie_gross_excel.sort_values(by = ['Date'], inplace=True, ascending=False)

# %%
weekend_movie_gross_excel
# Out:
#                                                Release     Opening  \
# 955                     Renaissance: A Film by Beyoncé  21801216.0
# 337  The Hunger Games: The Ballad of Songbirds & Sn...  44607143.0
# 627                               Trolls Band Together  30002525.0
# 322                                        The Marvels  46110859.0
# 116                            Five Nights at Freddy's  80001720.0
# ..                                                 ...         ...
# 642                 Indiana Jones and the Last Crusade  29355021.0
# 738                               Beverly Hills Cop II  26348555.0
# 774               Indiana Jones and the Temple of Doom  25337110.0
# 889         Star Wars: Episode VI - Return of the Jedi  23019618.0
# 469                               1997 Special Edition         NaN
#
#      Total Gross       Date                             Distributor
# 955   21801216.0 2023-12-01                                       -
# 337  125099432.0 2023-11-17                        Lions Gate Films
# 627   76474100.0 2023-11-17                      Universal Pictures
# 322   81419870.0 2023-11-10     Walt Disney Studios Motion Pictures
# 116  137038110.0 2023-10-27  Universal Pictures International (UPI)
# ..           ...        ...                                     ...
# 642  197171806.0 1989-05-24                      Paramount Pictures
# 738  153665036.0 1987-05-20                      Paramount Pictures
# 774  179870271.0 1984-05-23                      Paramount Pictures
# 889  252583617.0 1983-05-25                   Twentieth Century Fox
# 469          NaN        NaT                                     NaN
#
# [1000 rows x 5 columns]

# %%
startDate = pd.to_datetime('2014-01-01')
endDate = pd.to_datetime('2019-12-31')
filterDates = weekend_movie_gross_excel[(weekend_movie_gross_excel['Date'] >= startDate) & (weekend_movie_gross_excel['Date'] <= endDate)]
filterDates
# Out:
#                                            Release      Opening  Total Gross  \
# 14   Star Wars: Episode IX - The Rise of Skywalker  177383864.0  515202542.0
# 205                        Jumanji: The Next Level   59251543.0  320314960.0
# 721                                     Knives Out   26769548.0  165363234.0
# 42                                       Frozen II  130263358.0  477373578.0
# 567                                 Ford v Ferrari   31474958.0  117624357.0
# ..                                             ...          ...          ...
# 758                               About Last Night   25649011.0   48637684.0
# 968                                        RoboCop   21681430.0   58607007.0
# 945                              The Monuments Men   22003433.0   78031620.0
# 154                                 The Lego Movie   69050279.0  257760692.0
# 373                                     Ride Along   41516170.0  134938200.0
#
#           Date                          Distributor
# 14  2019-12-20  Walt Disney Studios Motion Pictures
# 205 2019-12-13    Sony Pictures Entertainment (SPE)
# 721 2019-11-27                     Lions Gate Films
# 42  2019-11-22  Walt Disney Studios Motion Pictures
# 567 2019-11-15                Twentieth Century Fox
# ..         ...                                  ...
# 758 2014-02-14                          Screen Gems
# 968 2014-02-12    Sony Pictures Entertainment (SPE)
# 945 2014-02-07    Sony Pictures Entertainment (SPE)
# 154 2014-02-07                         Warner Bros.
# 373 2014-01-17                   Universal Pictures
#
# [266 rows x 5 columns]

# %%
csv_file_path = r'C:\Users\mattl\code\SavvyCoders\Capstone\Data Sets\FirstWeekendData.csv'

# Save the DataFrame to a CSV file
filterDates.to_csv(csv_file_path, index=False)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to C:\Users\mattl\code\SavvyCoders\Capstone\Data Sets\FirstWeekendData.csv

# %%
movie_data = pd.read_csv(r"C:\Users\mattl\code\SavvyCoders\Capstone\Data Sets\Cumulative Movie Data.csv")
substring = '('
# string_data = movie_data['released'].str.split(substring).str.get(0).str.strip()
movie_data['Cleaned_released_date'] = movie_data['released'].str.split(substring).str.get(0).str.strip()
# date_object = datetime.strptime(str(string_data), "%B %d, %Y")
# movie_data['Clean_Release_Date'] = string_data
movie_data
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
#                               released  score      votes         director  \
# 0        June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2        June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3         July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4        July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
# ...                                ...    ...        ...              ...
# 7663  October 23, 2020 (United States)    3.1       18.0    Joseph Ebanks
# 7664  February 7, 2020 (United States)    4.7       36.0     Dusty Dukatz
# 7665         April 27, 2020 (Cameroon)    5.7       29.0     Nkanya Nkwai
# 7666   October 1, 2020 (United States)    NaN        NaN    James Randall
# 7667   August 19, 2020 (United States)    5.7        7.0     Pereko Mosia
#
#                        writer              star         country      budget  \
# 0                Stephen King    Jack Nicholson  United Kingdom  19000000.0
# 1     Henry De Vere Stacpoole    Brooke Shields   United States   4500000.0
# 2              Leigh Brackett       Mark Hamill   United States  18000000.0
# 3                Jim Abrahams       Robert Hays   United States   3500000.0
# 4          Brian Doyle-Murray       Chevy Chase   United States   6000000.0
# ...                       ...               ...             ...         ...
# 7663            Joseph Ebanks      Shannon Bond   United States      7000.0
# 7664              Lisa Huston  Michael Saquella   United States         NaN
# 7665             Lynno Lovert      Onyama Laura   United States     58750.0
# 7666            James Randall     Christina Roz   United States     15000.0
# 7667             Pereko Mosia  Siyabonga Mabaso    South Africa         NaN
#
#             gross                    company  runtime Cleaned_released_date
# 0      46998772.0               Warner Bros.    146.0         June 13, 1980
# 1      58853106.0          Columbia Pictures    104.0          July 2, 1980
# 2     538375067.0                  Lucasfilm    124.0         June 20, 1980
# 3      83453539.0         Paramount Pictures     88.0          July 2, 1980
# 4      39846344.0             Orion Pictures     98.0         July 25, 1980
# ...           ...                        ...      ...                   ...
# 7663          NaN                        NaN     90.0      October 23, 2020
# 7664          NaN  Cactus Blue Entertainment     90.0      February 7, 2020
# 7665          NaN           Embi Productions      NaN        April 27, 2020
# 7666          NaN                        NaN    120.0       October 1, 2020
# 7667          NaN                PK 65 Films    102.0       August 19, 2020
#
# [7668 rows x 16 columns]

# %%
movie_data
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
#                               released  score      votes         director  \
# 0        June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2        June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3         July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4        July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
# ...                                ...    ...        ...              ...
# 7663  October 23, 2020 (United States)    3.1       18.0    Joseph Ebanks
# 7664  February 7, 2020 (United States)    4.7       36.0     Dusty Dukatz
# 7665         April 27, 2020 (Cameroon)    5.7       29.0     Nkanya Nkwai
# 7666   October 1, 2020 (United States)    NaN        NaN    James Randall
# 7667   August 19, 2020 (United States)    5.7        7.0     Pereko Mosia
#
#                        writer              star         country      budget  \
# 0                Stephen King    Jack Nicholson  United Kingdom  19000000.0
# 1     Henry De Vere Stacpoole    Brooke Shields   United States   4500000.0
# 2              Leigh Brackett       Mark Hamill   United States  18000000.0
# 3                Jim Abrahams       Robert Hays   United States   3500000.0
# 4          Brian Doyle-Murray       Chevy Chase   United States   6000000.0
# ...                       ...               ...             ...         ...
# 7663            Joseph Ebanks      Shannon Bond   United States      7000.0
# 7664              Lisa Huston  Michael Saquella   United States         NaN
# 7665             Lynno Lovert      Onyama Laura   United States     58750.0
# 7666            James Randall     Christina Roz   United States     15000.0
# 7667             Pereko Mosia  Siyabonga Mabaso    South Africa         NaN
#
#             gross                    company  runtime Cleaned_released_date
# 0      46998772.0               Warner Bros.    146.0         June 13, 1980
# 1      58853106.0          Columbia Pictures    104.0          July 2, 1980
# 2     538375067.0                  Lucasfilm    124.0         June 20, 1980
# 3      83453539.0         Paramount Pictures     88.0          July 2, 1980
# 4      39846344.0             Orion Pictures     98.0         July 25, 1980
# ...           ...                        ...      ...                   ...
# 7663          NaN                        NaN     90.0      October 23, 2020
# 7664          NaN  Cactus Blue Entertainment     90.0      February 7, 2020
# 7665          NaN           Embi Productions      NaN        April 27, 2020
# 7666          NaN                        NaN    120.0       October 1, 2020
# 7667          NaN                PK 65 Films    102.0       August 19, 2020
#
# [7668 rows x 16 columns]

# %%
movie_data.drop(['rating', 'score', 'votes', 'director', 'writer', 'star', 'country', 'budget', 'company', 'runtime', 'released'], axis=1, inplace=True)

# %%
movie_data
# Out:
#                                                 name      genre  year  \
# 0                                        The Shining      Drama  1980
# 1                                    The Blue Lagoon  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     Action  1980
# 3                                          Airplane!     Comedy  1980
# 4                                         Caddyshack     Comedy  1980
# ...                                              ...        ...   ...
# 7663                                    More to Life      Drama  2020
# 7664                                     Dream Round     Comedy  2020
# 7665                                   Saving Mbango      Drama  2020
# 7666                                    It's Just Us      Drama  2020
# 7667                                       Tee em el     Horror  2020
#
#             gross Cleaned_released_date
# 0      46998772.0         June 13, 1980
# 1      58853106.0          July 2, 1980
# 2     538375067.0         June 20, 1980
# 3      83453539.0          July 2, 1980
# 4      39846344.0         July 25, 1980
# ...           ...                   ...
# 7663          NaN      October 23, 2020
# 7664          NaN      February 7, 2020
# 7665          NaN        April 27, 2020
# 7666          NaN       October 1, 2020
# 7667          NaN       August 19, 2020
#
# [7668 rows x 5 columns]

# %%
defined_date = Cleaned_released_date.datetime.strptime('June 13, 1980', '%m %d, %Y')
# correct_date = Cleaned_released_date.date.strftime("%Y/%m/%d")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\mattl\code\SavvyCoders\Capstone\Data Cleaning.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mattl/code/SavvyCoders/Capstone/Data%20Cleaning.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> defined_date = Cleaned_released_date.datetime.strptime('June 13, 1980', '%m %d, %Y')
#       <a href='vscode-notebook-cell:/c%3A/Users/mattl/code/SavvyCoders/Capstone/Data%20Cleaning.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> # correct_date = Cleaned_released_date.date.strftime("%Y/%m/%d")
#
# NameError: name 'Cleaned_released_date' is not defined

# %%
startDate = pd.to_datetime('January 1, 2014')
endDate = pd.to_datetime('December 31, 2019')
all_movies = movie_data[(movie_data['Cleaned_released_date'] >= startDate) & (movie_data['Cleaned_released_date'] <= endDate)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\mattl\code\SavvyCoders\Capstone\Data Cleaning.ipynb Cell 15 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/mattl/code/SavvyCoders/Capstone/Data%20Cleaning.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> startDate = pd.to_datetime('January 1, 2014')
#       <a href='vscode-notebook-cell:/c%3A/Users/mattl/code/SavvyCoders/Capstone/Data%20Cleaning.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> endDate = pd.to_datetime('December 31, 2019')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mattl/code/SavvyCoders/Capstone/Data%20Cleaning.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> all_movies = movie_data[(movie_data['Cleaned_released_date'] >= startDate) & (movie_data['Cleaned_released_date'] <= endDate)]
#
# File c:\Users\mattl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\mattl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File c:\Users\mattl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:5799, in Series._cmp_method(self, other, op)
#    5796 lvalues = self._values
#    5797 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5799 res_values = ops.comparison_op(lvalues, rvalues, op)
#    5801 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\mattl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:346, in comparison_op(left, right, op)
#     343     return invalid_comparison(lvalues, rvalues, op)
#     345 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 346     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     348 else:
#     349     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\mattl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:131, in comp_method_OBJECT_ARRAY(op, x, y)
#     129     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     130 else:
# --> 131     result = libops.scalar_compare(x.ravel(), y, op)
#     132 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'Timestamp'
